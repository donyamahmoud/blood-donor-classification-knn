# %%
import pandas as pd

# %%
df=pd.read_csv("/content/HepatitisCdata-selected-columns.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
# 5           6  0=Blood Donor   32   m  41.6  43.3  18.5  19.7  12.3   9.92
# 6           7  0=Blood Donor   32   m  46.3  41.3  17.5  17.8   8.5   7.01
# 7           8  0=Blood Donor   32   m  42.2  41.9  35.8  31.1  16.1   5.82
# 8           9  0=Blood Donor   32   m  50.9  65.5  23.2  21.2   6.9   8.69
# 9          10  0=Blood Donor   32   m  42.4  86.3  20.3  20.0  35.2   5.46

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df['Category'].value_counts()
# Out:
# Category
# 0=Blood Donor             533
# 3=Cirrhosis                30
# 1=Hepatitis                24
# 2=Fibrosis                 21
# 0s=suspect Blood Donor      7
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Category     0
# Age          0
# Sex          0
# ALB          1
# ALP         18
# ALT          1
# AST          0
# BIL          0
# CHE          0
# dtype: int64

# %%
c=["ALB","ALP","ALT"]
for col in c:
  df[col]=df[col].fillna(df[col].mean)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    object
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    object
#  3   ALB       615 non-null    object
#  4   ALP       615 non-null    object
#  5   ALT       615 non-null    object
#  6   AST       615 non-null    float64
#  7   BIL       615 non-null    float64
#  8   CHE       615 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 43.4+ KB

# %%
c=["ALB","ALP","ALT"]
df[c]=df[c].apply(pd.to_numeric,errors='coerce')

# %%
range=pd.DataFrame(
    {"min":df.min(numeric_only=True),
     "max":df.max(numeric_only=True)})

# %%
range
# Out:
#        min     max
# Age  19.00   77.00
# ALB  14.90   82.20
# ALP  11.30  416.60
# ALT   0.90  325.30
# AST  10.60  324.00
# BIL   0.80  254.00
# CHE   1.42   16.41

# %%
df.isna().sum()
# Out:
# Category     0
# Age          0
# Sex          0
# ALB          1
# ALP         18
# ALT          1
# AST          0
# BIL          0
# CHE          0
# dtype: int64

# %%
c=["ALB","ALP","ALT"]
for col in c:
  df[col]=df[col].fillna(df[col].mean())

# %%
df.isna().sum()
# Out:
# Category    0
# Age         0
# Sex         0
# ALB         0
# ALP         0
# ALT         0
# AST         0
# BIL         0
# CHE         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    object
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    object
#  3   ALB       615 non-null    float64
#  4   ALP       615 non-null    float64
#  5   ALT       615 non-null    float64
#  6   AST       615 non-null    float64
#  7   BIL       615 non-null    float64
#  8   CHE       615 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 43.4+ KB

# %%
df["Sex"]=df["Sex"].map({"m":0,"f":1})

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df["Category"]=encoder.fit_transform(df["Category"])

# %%
c=["Age","ALB","ALP","ALT","AST","BIL","CHE"]
for col in c:
  q1=df[col].quantile(0.25)
  q3=df[col].quantile(0.75)
  iqr=q3-q1
  lp=q1-1.5*iqr
  up=q3+1.5*iqr
  out=df[(df[col]<lp) | (df[col]>up)]
  print(len(out))
# Out:
# 1
# 27
# 14
# 36
# 64
# 47
# 24

# %%
for col in c:
  q1=df[col].quantile(0.25)
  q3=df[col].quantile(0.75)
  iqr=q3-q1
  lp=q1-1.5*iqr
  up=q3+1.5*iqr
  clean=df[(df[col]<lp) | (df[col]<=up)][col].median()
  df[col]=df[col].apply(lambda x:clean if (x<lp or x>up) else x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
from pandas.core.tools.datetimes import Scalar
x=df.drop(columns=["Category"])
y=df["Category"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train_numeric=x_train.drop(columns=["Sex"])
x_test_numeric=x_test.drop(columns=["Sex"])
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train_numeric)
x_test_scaled=scaler.transform(x_test_numeric)
x_train_sex=x_train["Sex"].values.reshape(-1,1)
x_test_sex=x_test["Sex"].values.reshape(-1,1)
x_train=np.column_stack((x_train_scaled,x_train_sex))
x_test=np.column_stack((x_test_scaled,x_test_sex))

# %%
x_train
# Out:
# array([[-0.83724906, -1.27739278,  0.27654904, ..., -0.43735444,
#         -1.41990337,  0.        ],
#        [-0.83724906,  0.89514449, -0.22894619, ..., -0.2122586 ,
#          0.21614454,  0.        ],
#        [ 0.60341332,  0.58815553, -0.30362162, ...,  0.06580097,
#         -0.71713365,  0.        ],
#        ...,
#        [ 1.22084006, -0.52172765, -0.98144477, ..., -0.2122586 ,
#         -0.40791497,  0.        ],
#        [ 0.08889104,  0.56454099, -0.80337259, ..., -0.86106427,
#          0.46914164,  1.        ],
#        [-0.63144015,  0.06863574, -0.60806761, ...,  0.83377503,
#         -0.60469049,  0.        ]])

# %%
from imblearn.over_sampling  import SMOTENC
categorical_features=[7]
smote_nc=SMOTENC(categorical_features=categorical_features,k_neighbors=3,random_state=42)
x_train_smote,y_train_smote=smote_nc.fit_resample(x_train,y_train)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=10,metric="euclidean")
knn.fit(x_train_smote,y_train_smote)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=10)

# %%
pred=knn.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.51      0.64        96
#            1       0.00      0.00      0.00         3
#            2       0.22      0.56      0.31         9
#            3       0.12      0.33      0.18         6
#            4       0.29      0.56      0.38         9
#
#     accuracy                           0.50       123
#    macro avg       0.30      0.39      0.30       123
# weighted avg       0.73      0.50      0.56       123
